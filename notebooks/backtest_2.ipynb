# %%
from src.mtal.backtesting.walk_forward import WalkForward
from src.mtal.backtesting.ma_atr import MAATR 

from src.mtal.data_collect import get_pair_df
from src.mtal.data_collect import get_spot_pairs
from src.mtal.dataviz import display_strategy_results 

cryptos = get_spot_pairs()
df = get_pair_df(pair="BTCUSDT", limit=900, frequency="1d")
ranges = {
        "short_ma": range(4, 10),
        "long_ma": range(4, 15),
        "ma_type": ["hma"],
}

results = WalkForward(df, MAATR, ranges).run()

for df, result in results:
    display_strategy_results(df, result)
# Out:
# (6, 7, 'hma')
# (4, 4, 'hma')
# (6, 7, 'hma')
# (4, 4, 'hma')
# (5, 11, 'hma')
# pnl: -68.18415703918163
# Win Rate: 0.16666666666666666
# Max drawdown: -0.06248359274610875
# Trade number: 6
# Excess return compared to B&H: 0.5294573259887824
# Kelly Criterion: -5.050593479338561
# pnl: 0
# Win Rate: 0
# Max drawdown: 0
# Trade number: 0
# Excess return compared to B&H: 0.48549646662890716
# Kelly Criterion: 0
# pnl: -230.18868697216044
# Win Rate: 0.0
# Max drawdown: -0.07564628323151641
# Trade number: 5
# Excess return compared to B&H: 0.16670471257209066
# Kelly Criterion: 0
# pnl: 0
# Win Rate: 0
# Max drawdown: 0
# Trade number: 0
# Excess return compared to B&H: 0.039807434568421715
# Kelly Criterion: 0
# pnl: 305.60445025456147
# Win Rate: 0.6666666666666666
# Max drawdown: -0.050929677510475606
# Trade number: 3
# Excess return compared to B&H: -0.12181325809249262
# Kelly Criterion: 11.173747986519656

# %%
from src.mtal.backtesting.ma_atr import MAATR 

from src.mtal.data_collect import get_pair_df
from src.mtal.dataviz import display_strategy_results 

df = get_pair_df(pair="BTCUSDT", limit=900, frequency="1d")
results = MAATR(df, short_ma=6, long_ma=9, ma_type="hma").run()
display_strategy_results(df, results)
# Out:
# pnl: 832.1366165349439
# Win Rate: 0.28846153846153844
# Max drawdown: -0.0786666867111253
# Trade number: 52
# Excess return compared to B&H: 0.40429884700426005
# Kelly Criterion: 5.27099287726371

# %%
from src.mtal.backtesting.walk_forward import WalkForward
from src.mtal.backtesting.bands import Keltner

from src.mtal.data_collect import get_pair_df
from src.mtal.data_collect import get_spot_pairs
from src.mtal.dataviz import display_strategy_results 

cryptos = get_spot_pairs()
df = get_pair_df(pair="BTCUSDT", limit=900, frequency="1d")
ranges = {
        "span": range(1, 20),
        "window_ATR": range(1, 15),
}

results = WalkForward(df, Keltner, ranges).run()

for df, result in results:
    display_strategy_results(df, result)
# Out:
# (1, 1)
# (1, 1)
# (11, 9)
# (7, 10)
# (7, 10)
# pnl: 0
# Win Rate: 0
# Max drawdown: 0
# Trade number: 0
# Excess return compared to B&H: 0.597641483027964
# Kelly Criterion: 0
# pnl: 0
# Win Rate: 0
# Max drawdown: 0
# Trade number: 0
# Excess return compared to B&H: 0.48549646662890716
# Kelly Criterion: 0
# pnl: -20.794494478708884
# Win Rate: 0.0
# Max drawdown: -0.020794494478708868
# Trade number: 1
# Excess return compared to B&H: 0.3760989050655422
# Kelly Criterion: 0
# pnl: 392.3155108302119
# Win Rate: 1.0
# Max drawdown: 0.392315510830212
# Trade number: 1
# Excess return compared to B&H: 0.43212294539863366
# Kelly Criterion: 100
# pnl: 83.9096865316651
# Win Rate: 1.0
# Max drawdown: 0.08390968653166514
# Trade number: 1
# Excess return compared to B&H: -0.343508021815389
# Kelly Criterion: 100

# %%
from src.mtal.backtesting.bands import Keltner

from src.mtal.data_collect import get_pair_df
from src.mtal.dataviz import display_strategy_results 

df = get_pair_df(pair="BTCUSDT", limit=900, frequency="1d")
results = Keltner(df, span=7, window_ATR=10).run()
display_strategy_results(df, results)
# Out:
# pnl: 532.2196675168675
# Win Rate: 0.8
# Max drawdown: -0.04412124536030509
# Trade number: 5
# Excess return compared to B&H: 0.10203605899989548
# Kelly Criterion: 16.56499305354556

# %%
from src.mtal.backtesting.walk_forward import WalkForward
from src.mtal.backtesting.bands import BB 

from src.mtal.data_collect import get_pair_df
from src.mtal.data_collect import get_spot_pairs
from src.mtal.dataviz import display_strategy_results 

cryptos = get_spot_pairs()
df = get_pair_df(pair="BTCUSDT", limit=900, frequency="1d")
ranges = {
        "window": range(1, 20),
        "window_dev": [2,2.2,2.4,2.6,2.8,3,3.2,3.4],
}

results = WalkForward(df, BB, ranges).run()

for df, result in results:
    display_strategy_results(df, result)
# Out:
# (1, 2)
# (1, 2)
# (14, 3)
# (14, 3)
# (19, 3)
# pnl: 0
# Win Rate: 0
# Max drawdown: 0
# Trade number: 0
# Excess return compared to B&H: 0.597641483027964
# Kelly Criterion: 0
# pnl: 0
# Win Rate: 0
# Max drawdown: 0
# Trade number: 0
# Excess return compared to B&H: 0.48549646662890716
# Kelly Criterion: 0
# pnl: 0
# Win Rate: 0
# Max drawdown: 0
# Trade number: 0
# Excess return compared to B&H: 0.3968933995442511
# Kelly Criterion: 0
# pnl: 0
# Win Rate: 0
# Max drawdown: 0
# Trade number: 0
# Excess return compared to B&H: 0.039807434568421715
# Kelly Criterion: 0
# pnl: 21.904529881262988
# Win Rate: 1.0
# Max drawdown: 0.02190452988126306
# Trade number: 1
# Excess return compared to B&H: -0.4055131784657911
# Kelly Criterion: 100

# %%
from src.mtal.backtesting.bands import BB 

from src.mtal.data_collect import get_pair_df
from src.mtal.dataviz import display_strategy_results 

df = get_pair_df(pair="BTCUSDT", limit=900, frequency="1d")
results = BB(df, window=19, window_dev=3).run()
display_strategy_results(df, results)
# Out:
# pnl: 565.1023271106014
# Win Rate: 0.6
# Max drawdown: -0.07833638727355036
# Trade number: 5
# Excess return compared to B&H: 0.13849922051014568
# Kelly Criterion: 9.29650885619313

# %%
from src.mtal.backtesting.walk_forward import WalkForward
from src.mtal.backtesting.bands import BB_silico 

from src.mtal.data_collect import get_pair_df
from src.mtal.data_collect import get_spot_pairs
from src.mtal.dataviz import display_strategy_results 

cryptos = get_spot_pairs()
df = get_pair_df(pair="BTCUSDT", limit=900, frequency="1d")
ranges = {
        "window": range(1, 20),
        "window_dev": [2,2.2,2.4,2.6,2.8,3,3.2,3.4],
}

results = WalkForward(df, BB_silico, ranges).run()

for df, result in results:
    display_strategy_results(df, result)
# Out:
# (19, 2.2)
# (7, 2)
# (6, 2)
# (6, 2)
# (6, 2)
# pnl: -7.381209270850263
# Win Rate: 0.0
# Max drawdown: -0.0073812092708502725
# Trade number: 1
# Excess return compared to B&H: 0.5902602737571138
# Kelly Criterion: 0
# pnl: 57.79472354255881
# Win Rate: 0.8333333333333334
# Max drawdown: -0.0035625122118236063
# Trade number: 6
# Excess return compared to B&H: 0.543291190171466
# Kelly Criterion: 220.07860921046463
# pnl: -32.57845415289387
# Win Rate: 0.5
# Max drawdown: -0.03471161891555227
# Trade number: 2
# Excess return compared to B&H: 0.3643149453913572
# Kelly Criterion: -211.85294386050023
# pnl: 31.17813218279298
# Win Rate: 1.0
# Max drawdown: 0.03117813218279302
# Trade number: 1
# Excess return compared to B&H: 0.07098556675121469
# Kelly Criterion: 100
# pnl: 32.46802285483432
# Win Rate: 0.6666666666666666
# Max drawdown: -0.01345562413259262
# Trade number: 3
# Excess return compared to B&H: -0.39494968549221976
# Kelly Criterion: 35.11251308349779

# %% [markdown]
# # Heikin ashin

# %%
from src.mtal.backtesting.walk_forward import WalkForward
from src.mtal.backtesting.heikin_ashin import HeikinAshin 

from src.mtal.data_collect import get_pair_df
from src.mtal.data_collect import get_spot_pairs
from src.mtal.dataviz import display_strategy_results 

cryptos = get_spot_pairs()
df = get_pair_df(pair="BTCUSDT", limit=900, frequency="1d")

ranges = {}

results = WalkForward(df, HeikinAshin, ranges).run()

for df, result in results:
    display_strategy_results(df, result)
# Out:
# None
# None
# None
# None
# None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 16
#      13 results = WalkForward(df, HeikinAshin, ranges).run()
#      15 for df, result in results:
# ---> 16     display_strategy_results(df, result)
#
# File ~/mtal/src/mtal/dataviz.py:192, in display_strategy_results(df, results)
#     191 def display_strategy_results(df: pd.DataFrame, results: BacktestResults):
# --> 192     display_strat_value_over_time(df, results)
#     193     print(f"pnl: {results.pnl}")
#     194     print(f"Win Rate: {results.win_rate}")
#
# File ~/mtal/src/mtal/dataviz.py:175, in display_strat_value_over_time(df, results)
#     173 def display_strat_value_over_time(df: pd.DataFrame, results: BacktestResults):
#     174     plt.figure(figsize=(10, 5))  # Taille de la figure
# --> 175     plt.plot(df["Close Time"], results.value_history, label="Valeur du Portefeuille")
#     176     plt.plot(
#     177         df["Close Time"],
#     178         results.b_n_h_history,
#     179         label="Benchmark Buy & Hold",
#     180         color="orange",
#     181     )
#     182     plt.title("Évolution de la Valeur du Portefeuille")  # Titre du graphique
#
# AttributeError: 'NoneType' object has no attribute 'value_history'

# %%
from src.mtal.backtesting.heikin_ashin import HeikinAshin 


from src.mtal.data_collect import get_pair_df
from src.mtal.dataviz import display_strategy_results 

df = get_pair_df(pair="BTCUSDT", limit=900, frequency="1d")
results = HeikinAshin(df).run()
display_strategy_results(df, results)
# Out:
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# pnl: 84.41567321010916
# Win Rate: 0.3614457831325301
# Max drawdown: -0.0859016541786207
# Trade number: 166
# Excess return compared to B&H: -0.2517844122666579
# Kelly Criterion: 5.422026032910081

# %% [markdown]
# # Heikin Hashin ema

# %%
from src.mtal.backtesting.walk_forward import WalkForward
from src.mtal.backtesting.heikin_ashin import HeikinAshinHMACross 

from src.mtal.data_collect import get_pair_df
from src.mtal.data_collect import get_spot_pairs
from src.mtal.dataviz import display_strategy_results 

cryptos = get_spot_pairs()
df = get_pair_df(pair="BTCUSDT", limit=900, frequency="1d")

ranges = {
        "short_ma": range(4, 10),
        "long_ma": range(4, 15),
}

results = WalkForward(df, HeikinAshinHMACross, ranges).run()

for df, result in results:
    display_strategy_results(df, result)
# Out:
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# (4, 8)
# pnl: -261.47486771810827
# Win Rate: 0.25
# Max drawdown: -0.09935660678787192
# Trade number: 8
# Excess return compared to B&H: 0.3607067104909511
# Kelly Criterion: -16.47050493548695
# pnl: 0
# Win Rate: 0
# Max drawdown: 0
# Trade number: 0
# Excess return compared to B&H: 0.44497899390591134
# Kelly Criterion: 0
# pnl: 56.497936150309215
# Win Rate: 0.3684210526315789
# Max drawdown: -0.05154040049916475
# Trade number: 19
# Excess return compared to B&H: 0.48644428896300684
# Kelly Criterion: 14.919192662012255
# pnl: 197.15494652007055
# Win Rate: 0.5625
# Max drawdown: -0.04531413447480797
# Trade number: 16
# Excess return compared to B&H: 0.3469906795389045
# Kelly Criterion: 29.937763832077046
# pnl: 607.8326386947833
# Win Rate: 0.6666666666666666
# Max drawdown: -0.0859016541786207
# Trade number: 15
# Excess return compared to B&H: 0.22806142595247525
# Kelly Criterion: 12.990386269300682

# %%
from src.mtal.backtesting.heikin_ashin import HeikinAshinHMACross 


from src.mtal.data_collect import get_pair_df
from src.mtal.dataviz import display_strategy_results 

df = get_pair_df(pair="BTCUSDT", limit=900, frequency="1d")
results = HeikinAshinHMACross(df, short_ma=6, long_ma=9).run()
display_strategy_results(df, results)
# Out:
# /home/romain/mtal/src/mtal/analysis.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Open"] = df.iloc[0]["Open"]
# /home/romain/mtal/src/mtal/analysis.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Close"] = (
# /home/romain/mtal/src/mtal/analysis.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["High"] = df.iloc[0]["High"]
# /home/romain/mtal/src/mtal/analysis.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heikin_ashi_df.iloc[0]["Low"] = df.iloc[0]["Low"]
# pnl: 1774.7825265808142
# Win Rate: 0.42105263157894735
# Max drawdown: -0.09337795626952249
# Trade number: 95
# Excess return compared to B&H: 1.4379542622631583
# Kelly Criterion: 7.225250328861549
