# %% [markdown]
# # Crypto data Collection

# %%
from src.rsi_detector.data_collect import get_spot_pairs

cryptos = get_spot_pairs()

# %%
from src.rsi_detector.data_collect import get_pair_df

df = get_pair_df(pair="LTCUSDT")
df.head()
# Out:
#    Open Time    Open    High     Low   Close        Volume  \
# 0 2017-12-11  272.00  330.00  239.99  311.40   59561.28759
# 1 2017-12-18  311.23  366.96  177.58  262.90  251577.24855
# 2 2017-12-25  262.90  284.34  193.20  223.69  223926.94979
# 3 2018-01-01  223.69  315.00  212.74  269.01  442699.93154
# 4 2018-01-08  269.01  271.82  195.03  234.12  435643.98700
#
#                Close Time
# 0 2017-12-17 23:59:59.999
# 1 2017-12-24 23:59:59.999
# 2 2017-12-31 23:59:59.999
# 3 2018-01-07 23:59:59.999
# 4 2018-01-14 23:59:59.999

# %% [markdown]
# # Stocks data collection

# %%
from src.rsi_detector.data_collect import get_ticker_names 

tickers = get_ticker_names()

# %%
from src.rsi_detector.data_collect import get_stock_data

df = get_stock_data(tickers[0])
# df

# %% [markdown]
# # Compute and analysis

# %%
from src.rsi_detector.analysis import compute_rsi

df_rsi = compute_rsi(df)

df_rsi.tail()
# Out:
#            Date  Open  High   Low  Close  Adjusted_close  Volume  Close Time  \
# 215  2024-03-11  26.2  26.6  25.4   26.2            26.2     435  2024-03-11
# 216  2024-03-18  26.0  26.2  25.2   25.2            25.2     420  2024-03-18
# 217  2024-03-25  26.2  26.2  25.2   26.0            26.0     128  2024-03-25
# 218  2024-04-02  25.2  26.2  25.0   25.0            25.0    1054  2024-04-02
# 219  2024-04-08  26.0  26.2  25.0   25.0            25.0     175  2024-04-08
#
#      Change  Gain  Loss  Avg Gain  Avg Loss        RS       ema5        RSI  \
# 215     0.0   0.0  -0.0  0.344328  0.329687  1.044408  26.088532  51.086092
# 216    -1.0   0.0   1.0  0.319733  0.377566  0.846826  25.792355  45.853034
# 217     0.8   0.8  -0.0  0.354038  0.350597  1.009813  25.861570  50.244120
# 218    -1.0   0.0   1.0  0.328749  0.396983  0.828119  25.574380  45.298956
# 219     0.0   0.0  -0.0  0.305267  0.368627  0.828119  25.382920  45.298956
#
#      Volume_MA
# 215     292.90
# 216     308.55
# 217     291.65
# 218     342.30
# 219     335.25

# %%
from src.rsi_detector.dataviz import get_x_y_from_df, plot_rsi_with_line

plot_rsi_with_line(*get_x_y_from_df(df_rsi, 7, 10), df_rsi, limit=10)

# %%
import pandas as pd

data = {
        "Date": [
            "2024-02-05",
            "2024-02-12",
            "2024-02-19",
            "2024-02-26",
            "2024-03-04",
            "2024-03-11",
            "2024-03-18",
# 18  2024-04-08  26.0  26.2  25.0   25.0     175   70  25.382920     300.00

# %%
df_rsi.iloc[-10:]
# Out:
#            Date  Open  High   Low  Close  Adjusted_close  Volume  Close Time  \
# 210  2024-02-05  25.4  26.8  24.8   26.0            26.0     657  2024-02-05
# 211  2024-02-12  27.0  27.0  25.4   26.4            26.4     259  2024-02-12
# 212  2024-02-19  26.8  26.8  25.4   25.6            25.6     383  2024-02-19
# 213  2024-02-26  26.8  26.8  25.4   25.8            25.8     298  2024-02-26
# 214  2024-03-04  25.8  26.2  25.4   26.2            26.2      83  2024-03-04
# 215  2024-03-11  26.2  26.6  25.4   26.2            26.2     435  2024-03-11
# 216  2024-03-18  26.0  26.2  25.2   25.2            25.2     420  2024-03-18
# 217  2024-03-25  26.2  26.2  25.2   26.0            26.0     128  2024-03-25
# 218  2024-04-02  25.2  26.2  25.0   25.0            25.0    1054  2024-04-02
# 219  2024-04-08  26.0  26.2  25.0   25.0            25.0     175  2024-04-08
#
#      Change  Gain  Loss  Avg Gain  Avg Loss        RS       ema5        RSI  \
# 210    -0.4   0.0   0.4  0.411722  0.411285  1.001065  26.153542  50.026604
# 211     0.4   0.4  -0.0  0.410885  0.381907  1.075877  26.235695  51.827594
# 212    -0.8   0.0   0.8  0.381536  0.411771  0.926574  26.023796  48.094391
# 213     0.2   0.2  -0.0  0.368569  0.382359  0.963936  25.949198  49.081847
# 214     0.4   0.4  -0.0  0.370814  0.355047  1.044408  26.032798  51.086092
# 215     0.0   0.0  -0.0  0.344328  0.329687  1.044408  26.088532  51.086092
# 216    -1.0   0.0   1.0  0.319733  0.377566  0.846826  25.792355  45.853034
# 217     0.8   0.8  -0.0  0.354038  0.350597  1.009813  25.861570  50.244120
# 218    -1.0   0.0   1.0  0.328749  0.396983  0.828119  25.574380  45.298956
# 219     0.0   0.0  -0.0  0.305267  0.368627  0.828119  25.382920  45.298956
#
#      Volume_MA
# 210     313.15
# 211     322.90
# 212     332.15
# 213     325.55
# 214     272.85
# 215     292.90
# 216     308.55
# 217     291.65
# 218     342.30
# 219     335.25

# %%
from src.rsi_detector.analysis import compute_and_validate_2_combinations
from src.rsi_detector.dataviz import display_top_k_lines

best_lines = compute_and_validate_2_combinations(df_rsi.iloc[-100:])
if best_lines:
    display_top_k_lines(best_lines, df_rsi, top_k=3)

# %% [markdown]
# # Visualisation
# ## Cryptos

# %%
from src.rsi_detector import screen_best_asset

screen_best_asset(limit=10)

# %% [markdown]
# ## Stocks

# %%
from src.rsi_detector import screen_best_stocks

screen_best_stocks(limit=400)
